# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
import warnings

warnings.filterwarnings("ignore", category=UserWarning)
# Read the data
df = pd.read_csv('hi1_20170701_20200609.csv')

# Check column names
print("Column names:", df.columns.tolist())
print("First few rows:")
print(df.head())

# Assuming the first column is date and second is time, but they might have different names
date_col = df.columns[0]
time_col = df.columns[1]
print(f"Using '{date_col}' as date column and '{time_col}' as time column")

# Convert date and time to proper format
df[date_col] = df[date_col].astype(str)
df[time_col] = df[time_col].astype(str).str.zfill(6)

# Convert price and volume columns to numeric
price_cols = [col for col in df.columns[2:]]
for col in price_cols:
    df[col] = pd.to_numeric(df[col])

# Initialize variables for tracking
daily_profits = []
total_profit = 0
max_daily_loss = -200  # Stop trading if flat position loss exceeds this value
unique_dates = df[date_col].unique()

# Process each trading day
for date in unique_dates:
    day_data = df[df[date_col] == date].reset_index(drop=True)
    
    if len(day_data) < 52:  # Skip days with insufficient data
        print(f"Date {date}: Insufficient data points, skipping")
        daily_profits.append(0)
        continue
    
    # Initialize daily variables
    position = 0  # 0 = flat, positive = long, negative = short
    day_profit = 0
    
    # Determine the last 60 minutes index
    last_60_min_index = max(0, len(day_data) - 60)
    
    # Start trading from the 52nd minute
    for i in range(51, len(day_data)):
        # Check if daily loss limit exceeded (when in flat position)
        if position == 0 and day_profit < max_daily_loss:
            print(f"Date {date}: Daily loss of {day_profit:.2f} exceeds limit of {max_daily_loss}. Stopping trading for today.")
            break
            
        current_price = day_data.iloc[i, df.columns.get_loc('hi1_close')]
        
        # Check if this is the last minute of the day
        is_last_minute = (i == len(day_data) - 1)
        
        # Check if we're in the last 60 minutes
        is_last_60_min = (i >= last_60_min_index)
        
        # If not the last minute, make prediction using ARIMA(1,1,1)
        if not is_last_minute:
            # Get the last 50 closing prices
            history = day_data.iloc[i-50:i+1, df.columns.get_loc('hi1_close')].values
            
            try:
                # Fit ARIMA model
                model = ARIMA(history, order=(1, 1, 1))
                model_fit = model.fit()
                
                # Make one-step forecast
                forecast = model_fit.forecast(steps=1)[0]
                predicted_change = forecast - current_price
            except:
                # If ARIMA fails, assume no change
                predicted_change = 0
        
        # Force liquidation at the end of the day
        if is_last_minute and position != 0:
            if position > 0:  # Long position
                # Sell all contracts
                day_profit += position * (current_price - 2)
                print(f"Date {date}, Time {day_data.iloc[i][time_col]}: End of day - Liquidating {position} long contracts at {current_price}")
                position = 0
            else:  # Short position
                # Buy back all contracts
                day_profit -= abs(position) * (current_price + 2)
                print(f"Date {date}, Time {day_data.iloc[i][time_col]}: End of day - Liquidating {abs(position)} short contracts at {current_price}")
                position = 0
        
        # Execute trading strategy if not the last minute
        elif not is_last_minute:
            # In the last 60 minutes, only allow closing positions, not opening new ones
            if is_last_60_min:
                if position > 0 and predicted_change < -2:  # Long position and prediction to decrease
                    day_profit += position * (current_price - 2)
                    print(f"Date {date}, Time {day_data.iloc[i][time_col]}: Last 60 min - Closing {position} long contracts at {current_price}")
                    position = 0
                elif position < 0 and predicted_change > 2:  # Short position and prediction to increase
                    day_profit -= abs(position) * (current_price + 2)
                    print(f"Date {date}, Time {day_data.iloc[i][time_col]}: Last 60 min - Closing {abs(position)} short contracts at {current_price}")
                    position = 0
            else:
                # Normal trading logic for non-last 60 minutes
                margin_requirement = abs(position + 1) * current_price * 0.1  # 10% margin
                
                # Case 1: Currently flat
                if position == 0:
                    if predicted_change > 2:  # Buy signal
                        if margin_requirement <= 15000:
                            position = 1
                            day_profit -= (current_price + 2)  # Buy price + commission
                            #print(f"Date {date}, Time {day_data.iloc[i][time_col]}: Buy 1 contract at {current_price}, predicted change: {predicted_change:.2f}")
                    elif predicted_change < -2:  # Sell signal
                        if margin_requirement <= 15000:
                            position = -1
                            day_profit += (current_price - 2)  # Sell price - commission
                            #print(f"Date {date}, Time {day_data.iloc[i][time_col]}: Sell 1 contract at {current_price}, predicted change: {predicted_change:.2f}")
                
                # Case 2: Currently long
                elif position > 0:
                    if predicted_change > 2:  # Buy more
                        margin_requirement = (position + 1) * current_price * 0.1
                        if margin_requirement <= 15000:
                            position += 1
                            day_profit -= (current_price + 2)
                            #print(f"Date {date}, Time {day_data.iloc[i][time_col]}: Buy 1 more contract at {current_price}, predicted change: {predicted_change:.2f}")
                    elif predicted_change < -2:  # Liquidate all
                        day_profit += position * (current_price - 2)
                        #print(f"Date {date}, Time {day_data.iloc[i][time_col]}: Sell {position} contracts at {current_price}, predicted change: {predicted_change:.2f}")
                        position = 0
                
                # Case 3: Currently short
                else:  # position < 0
                    if predicted_change < -2:  # Sell more
                        margin_requirement = (abs(position) + 1) * current_price * 0.1
                        if margin_requirement <= 15000:
                            position -= 1
                            day_profit += (current_price - 2)
                            #print(f"Date {date}, Time {day_data.iloc[i][time_col]}: Sell 1 more contract at {current_price}, predicted change: {predicted_change:.2f}")
                    elif predicted_change > 2:  # Liquidate all
                        day_profit -= abs(position) * (current_price + 2)
                        #print(f"Date {date}, Time {day_data.iloc[i][time_col]}: Buy back {abs(position)} contracts at {current_price}, predicted change: {predicted_change:.2f}")
                        position = 0
    
    # Record daily profit
    daily_profits.append(day_profit)
    total_profit += day_profit
    print(f"Date {date}: Daily P&L = {day_profit:.2f} HSI points")
# Out:
# Column names: ['date', 'time', 'hi1_open', 'hi1_high', 'hi1_low', 'hi1_close', 'hi1_volume']
# First few rows:
#        date   time  hi1_open  hi1_high  hi1_low  hi1_close  hi1_volume
# 0  20170703  91400   25524.0   25524.0  25524.0    25524.0       639.0
# 1  20170703  91500   25530.0   25557.0  25506.0    25547.0       941.0
# 2  20170703  91600   25549.0   25564.0  25547.0    25560.0       371.0
# 3  20170703  91700   25558.0   25568.0  25549.0    25568.0       383.0
# 4  20170703  91800   25568.0   25574.0  25558.0    25562.0       288.0
# Using 'date' as date column and 'time' as time column
# Date 20170703, Time 234400: End of day - Liquidating 1 long contracts at 25764.0
# Date 20170703: Daily P&L = 372.00 HSI points
# Date 20170704: Daily loss of -328.00 exceeds limit of -200. Stopping trading for today.
# Date 20170704: Daily P&L = -328.00 HSI points
# Date 20170705: Daily loss of -213.00 exceeds limit of -200. Stopping trading for today.
# Date 20170705: Daily P&L = -213.00 HSI points
# Date 20170706, Time 224800: Last 60 min - Closing 1 short contracts at 25361.0
# Date 20170706: Daily P&L = -137.00 HSI points
# Date 20170707: Daily P&L = -167.00 HSI points
# Date 20170710: Daily loss of -366.00 exceeds limit of -200. Stopping trading for today.
# Date 20170710: Daily P&L = -366.00 HSI points
# Date 20170711: Daily loss of -230.00 exceeds limit of -200. Stopping trading for today.
# Date 20170711: Daily P&L = -230.00 HSI points
# Date 20170712, Time 224800: Last 60 min - Closing 5 long contracts at 26284.0
# Date 20170712: Daily P&L = 204.00 HSI points
# Date 20170713, Time 234400: End of day - Liquidating 1 long contracts at 26378.0
# Date 20170713: Daily P&L = 165.00 HSI points
# Date 20170714: Daily loss of -223.00 exceeds limit of -200. Stopping trading for today.
# Date 20170714: Daily P&L = -223.00 HSI points
# Date 20170717, Time 234400: End of day - Liquidating 1 long contracts at 26454.0
# Date 20170717: Daily P&L = -27.00 HSI points
# Date 20170718, Time 233200: Last 60 min - Closing 5 long contracts at 26510.0
# Date 20170718: Daily loss of -236.00 exceeds limit of -200. Stopping trading for today.
# Date 20170718: Daily P&L = -236.00 HSI points
# Date 20170719: Daily P&L = 87.00 HSI points
# Date 20170720, Time 234400: End of day - Liquidating 4 long contracts at 26759.0
# Date 20170720: Daily P&L = -33.00 HSI points
# Date 20170721: Daily P&L = 41.00 HSI points
# Date 20170724, Time 234400: End of day - Liquidating 3 long contracts at 26828.0
# Date 20170724: Daily P&L = -285.00 HSI points
# Date 20170725, Time 231900: Last 60 min - Closing 1 long contracts at 26941.0
# Date 20170725: Daily P&L = 69.00 HSI points
# Date 20170726: Daily P&L = -60.00 HSI points
# Date 20170727, Time 234400: End of day - Liquidating 1 long contracts at 27115.0
# Date 20170727: Daily P&L = 156.00 HSI points
# Date 20170728, Time 224500: Last 60 min - Closing 1 short contracts at 26947.0
# Date 20170728: Daily P&L = 10019.00 HSI points
# Date 20170731: Daily loss of -257.00 exceeds limit of -200. Stopping trading for today.
# Date 20170731: Daily P&L = -257.00 HSI points
# Date 20170801: Daily loss of -475.00 exceeds limit of -200. Stopping trading for today.
# Date 20170801: Daily P&L = -475.00 HSI points
# Date 20170802, Time 225000: Last 60 min - Closing 2 long contracts at 27501.0
# Date 20170802: Daily P&L = 504.00 HSI points
# Date 20170803: Daily loss of -233.00 exceeds limit of -200. Stopping trading for today.
# Date 20170803: Daily P&L = -233.00 HSI points
# Date 20170804, Time 234400: End of day - Liquidating 1 short contracts at 27528.0
# Date 20170804: Daily P&L = -198.00 HSI points
# Date 20170807, Time 224500: Last 60 min - Closing 1 long contracts at 27557.0
# Date 20170807: Daily P&L = 142.00 HSI points
# Date 20170808: Daily loss of -214.00 exceeds limit of -200. Stopping trading for today.
# Date 20170808: Daily P&L = -214.00 HSI points
# Date 20170809: Daily loss of -223.00 exceeds limit of -200. Stopping trading for today.
# Date 20170809: Daily P&L = -223.00 HSI points
# Date 20170810: Daily P&L = -89.00 HSI points
# Date 20170811: Daily loss of -202.00 exceeds limit of -200. Stopping trading for today.
# Date 20170811: Daily P&L = -202.00 HSI points
# Date 20170814: Daily loss of -457.00 exceeds limit of -200. Stopping trading for today.
# Date 20170814: Daily P&L = -457.00 HSI points
# Date 20170815: Daily P&L = 671.00 HSI points
# Date 20170816, Time 234400: End of day - Liquidating 1 long contracts at 27560.0
# Date 20170816: Daily P&L = 894.00 HSI points
# Date 20170817: Daily loss of -255.00 exceeds limit of -200. Stopping trading for today.
# Date 20170817: Daily P&L = -255.00 HSI points
# Date 20170818: Daily loss of -204.00 exceeds limit of -200. Stopping trading for today.
# Date 20170818: Daily P&L = -204.00 HSI points
# Date 20170821, Time 231300: Last 60 min - Closing 1 long contracts at 27207.0
# Date 20170821: Daily P&L = 87.00 HSI points
# Date 20170822: Daily P&L = 67.00 HSI points
# Date 20170824, Time 225500: Last 60 min - Closing 1 long contracts at 27579.0
# Date 20170824: Daily P&L = 348.00 HSI points
# Date 20170825: Daily loss of -240.00 exceeds limit of -200. Stopping trading for today.
# Date 20170825: Daily P&L = -240.00 HSI points
# Date 20170828: Daily loss of -204.00 exceeds limit of -200. Stopping trading for today.
# Date 20170828: Daily P&L = -204.00 HSI points
# Date 20170829, Time 230000: Last 60 min - Closing 5 short contracts at 27822.0
# Date 20170829: Daily P&L = -180.00 HSI points
# Date 20170830: Daily loss of -374.00 exceeds limit of -200. Stopping trading for today.
# Date 20170830: Daily P&L = -374.00 HSI points
# Date 20170831, Time 234400: End of day - Liquidating 1 short contracts at 27943.0
# Date 20170831: Daily P&L = 184.00 HSI points
# Date 20170901, Time 234400: End of day - Liquidating 4 long contracts at 27954.0
# Date 20170901: Daily P&L = 100.00 HSI points
# Date 20170904, Time 233100: Last 60 min - Closing 4 short contracts at 27801.0
# Date 20170904: Daily P&L = -40.00 HSI points
# Date 20170905: Daily loss of -235.00 exceeds limit of -200. Stopping trading for today.
# Date 20170905: Daily P&L = -235.00 HSI points
# Date 20170906: Daily loss of -217.00 exceeds limit of -200. Stopping trading for today.
# Date 20170906: Daily P&L = -217.00 HSI points
# Date 20170907: Daily loss of -231.00 exceeds limit of -200. Stopping trading for today.
# Date 20170907: Daily P&L = -231.00 HSI points
# Date 20170908: Daily loss of -494.00 exceeds limit of -200. Stopping trading for today.
# Date 20170908: Daily P&L = -494.00 HSI points
# Date 20170911: Daily P&L = 29.00 HSI points
# Date 20170912: Daily P&L = -101.00 HSI points
# Date 20170913, Time 234400: End of day - Liquidating 3 long contracts at 27788.0
# Date 20170913: Daily P&L = -230.00 HSI points
# Date 20170914: Daily loss of -252.00 exceeds limit of -200. Stopping trading for today.
# Date 20170914: Daily P&L = -252.00 HSI points
# Date 20170915, Time 234400: End of day - Liquidating 1 long contracts at 27822.0
# Date 20170915: Daily P&L = 764.00 HSI points
# Date 20170918: Daily loss of -224.00 exceeds limit of -200. Stopping trading for today.
# Date 20170918: Daily P&L = -224.00 HSI points
# Date 20170919: Daily loss of -221.00 exceeds limit of -200. Stopping trading for today.
# Date 20170919: Daily P&L = -221.00 HSI points
# Date 20170920, Time 231200: Last 60 min - Closing 2 long contracts at 28108.0
# Date 20170920: Daily P&L = 45.00 HSI points
# Date 20170921, Time 234400: End of day - Liquidating 3 long contracts at 28057.0
# Date 20170921: Daily P&L = -301.00 HSI points
# Date 20170922, Time 234400: End of day - Liquidating 1 short contracts at 27810.0
# Date 20170922: Daily P&L = -189.00 HSI points
# Date 20170925: Daily loss of -435.00 exceeds limit of -200. Stopping trading for today.
# Date 20170925: Daily P&L = -435.00 HSI points
# Date 20170926: Daily loss of -269.00 exceeds limit of -200. Stopping trading for today.
# Date 20170926: Daily P&L = -269.00 HSI points
# Date 20170927, Time 233500: Last 60 min - Closing 1 short contracts at 27502.0
# Date 20170927: Daily P&L = 485.00 HSI points
# Date 20170928, Time 154500: Last 60 min - Closing 2 short contracts at 27429.0
# Date 20170928: Daily P&L = 118.00 HSI points
# Date 20170929: Daily loss of -232.00 exceeds limit of -200. Stopping trading for today.
# Date 20170929: Daily P&L = -232.00 HSI points
# Date 20171003: Daily loss of -328.00 exceeds limit of -200. Stopping trading for today.
# Date 20171003: Daily P&L = -328.00 HSI points
# Date 20171004: Daily P&L = -61.00 HSI points
# Date 20171006, Time 225700: Last 60 min - Closing 5 short contracts at 28332.0
# Date 20171006: Daily P&L = -62.00 HSI points
# Date 20171009, Time 234400: End of day - Liquidating 1 short contracts at 28325.0
# Date 20171009: Daily P&L = -127.00 HSI points
# Date 20171010: Daily P&L = -92.00 HSI points
# Date 20171011: Daily loss of -262.00 exceeds limit of -200. Stopping trading for today.
# Date 20171011: Daily P&L = -262.00 HSI points
# Date 20171012: Daily loss of -288.00 exceeds limit of -200. Stopping trading for today.
# Date 20171012: Daily P&L = -288.00 HSI points
# Date 20171013, Time 234400: End of day - Liquidating 5 short contracts at 28612.0
# Date 20171013: Daily P&L = -347.00 HSI points
# Date 20171016: Daily loss of -230.00 exceeds limit of -200. Stopping trading for today.
# Date 20171016: Daily P&L = -230.00 HSI points
# Date 20171017: Daily P&L = -164.00 HSI points
# Date 20171018: Daily loss of -232.00 exceeds limit of -200. Stopping trading for today.
# Date 20171018: Daily P&L = -232.00 HSI points
# Date 20171019: Daily loss of -222.00 exceeds limit of -200. Stopping trading for today.
# Date 20171019: Daily P&L = -222.00 HSI points
# Date 20171020: Daily P&L = 64.00 HSI points
# Date 20171023: Daily P&L = -36.00 HSI points
# Date 20171024: Daily loss of -247.00 exceeds limit of -200. Stopping trading for today.
# Date 20171024: Daily P&L = -247.00 HSI points
# Date 20171025, Time 230400: Last 60 min - Closing 1 long contracts at 28122.0
# Date 20171025: Daily P&L = 271.00 HSI points
# Date 20171026, Time 231600: Last 60 min - Closing 1 long contracts at 28324.0
# Date 20171026: Daily P&L = -157.00 HSI points
# Date 20171027: Daily loss of -301.00 exceeds limit of -200. Stopping trading for today.
# Date 20171027: Daily P&L = -301.00 HSI points
# Date 20171030: Daily loss of -270.00 exceeds limit of -200. Stopping trading for today.
# Date 20171030: Daily P&L = -270.00 HSI points
# Date 20171031, Time 234400: End of day - Liquidating 1 short contracts at 28257.0
# Date 20171031: Daily P&L = -211.00 HSI points
# Date 20171101, Time 233500: Last 60 min - Closing 2 short contracts at 28599.0
# Date 20171101: Daily P&L = -52.00 HSI points
# Date 20171102: Daily P&L = -70.00 HSI points
# Date 20171103, Time 230000: Last 60 min - Closing 2 short contracts at 28511.0
# Date 20171103: Daily P&L = 180.00 HSI points
# Date 20171106, Time 232500: Last 60 min - Closing 1 long contracts at 28639.0
# Date 20171106: Daily P&L = 89.00 HSI points
# Date 20171107: Daily loss of -355.00 exceeds limit of -200. Stopping trading for today.
# Date 20171107: Daily P&L = -355.00 HSI points
# Date 20171108: Daily loss of -227.00 exceeds limit of -200. Stopping trading for today.
# Date 20171108: Daily P&L = -227.00 HSI points
# Date 20171109: Daily loss of -234.00 exceeds limit of -200. Stopping trading for today.
# Date 20171109: Daily P&L = -234.00 HSI points
# Date 20171110, Time 232200: Last 60 min - Closing 3 long contracts at 29057.0
# Date 20171110: Daily P&L = -9.00 HSI points
# Date 20171113, Time 232600: Last 60 min - Closing 1 long contracts at 29143.0
# Date 20171113: Daily P&L = -133.00 HSI points
# Date 20171114, Time 234700: Last 60 min - Closing 1 short contracts at 29134.0
# Date 20171114: Daily P&L = 136.00 HSI points
# Date 20171115: Daily P&L = 189.00 HSI points
# Date 20171116, Time 235900: End of day - Liquidating 1 short contracts at 29214.0
# Date 20171116: Daily P&L = -225.00 HSI points
# Date 20171117, Time 230100: Last 60 min - Closing 2 short contracts at 29139.0
# Date 20171117: Daily P&L = 324.00 HSI points
# Date 20171120, Time 235900: End of day - Liquidating 5 short contracts at 29286.0
# Date 20171120: Daily P&L = -393.00 HSI points
# Date 20171121: Daily loss of -334.00 exceeds limit of -200. Stopping trading for today.
# Date 20171121: Daily P&L = -334.00 HSI points
# Date 20171122: Daily loss of -287.00 exceeds limit of -200. Stopping trading for today.
# Date 20171122: Daily P&L = -287.00 HSI points
# Date 20171123: Daily loss of -428.00 exceeds limit of -200. Stopping trading for today.
# Date 20171123: Daily P&L = -428.00 HSI points
# Date 20171124: Daily loss of -245.00 exceeds limit of -200. Stopping trading for today.
# Date 20171124: Daily P&L = -245.00 HSI points
# Date 20171127: Daily loss of -227.00 exceeds limit of -200. Stopping trading for today.
# Date 20171127: Daily P&L = -227.00 HSI points
# Date 20171128, Time 235900: End of day - Liquidating 1 short contracts at 29691.0
# Date 20171128: Daily P&L = 258.00 HSI points
# Date 20171129: Daily loss of -254.00 exceeds limit of -200. Stopping trading for today.
# Date 20171129: Daily P&L = -254.00 HSI points
# Date 20171130: Daily loss of -222.00 exceeds limit of -200. Stopping trading for today.
# Date 20171130: Daily P&L = -222.00 HSI points
# Date 20171201: Daily loss of -243.00 exceeds limit of -200. Stopping trading for today.
# Date 20171201: Daily P&L = -243.00 HSI points
# Date 20171204: Daily loss of -207.00 exceeds limit of -200. Stopping trading for today.
# Date 20171204: Daily P&L = -207.00 HSI points
# Date 20171205: Daily loss of -381.00 exceeds limit of -200. Stopping trading for today.
# Date 20171205: Daily P&L = -381.00 HSI points
# Date 20171206: Daily loss of -330.00 exceeds limit of -200. Stopping trading for today.
# Date 20171206: Daily P&L = -330.00 HSI points
# Date 20171207, Time 232000: Last 60 min - Closing 4 short contracts at 28415.0
# Date 20171207: Daily loss of -285.00 exceeds limit of -200. Stopping trading for today.
# Date 20171207: Daily P&L = -285.00 HSI points
# Date 20171208: Daily loss of -420.00 exceeds limit of -200. Stopping trading for today.
# Date 20171208: Daily P&L = -420.00 HSI points
# Date 20171211: Daily P&L = -41.00 HSI points
# Date 20171212, Time 235900: End of day - Liquidating 2 short contracts at 28749.0
# Date 20171212: Daily P&L = 857.00 HSI points
# Date 20171213: Daily loss of -204.00 exceeds limit of -200. Stopping trading for today.
# Date 20171213: Daily P&L = -204.00 HSI points
# Date 20171214: Daily loss of -267.00 exceeds limit of -200. Stopping trading for today.
# Date 20171214: Daily P&L = -267.00 HSI points
# Date 20171215: Daily loss of -223.00 exceeds limit of -200. Stopping trading for today.
# Date 20171215: Daily P&L = -223.00 HSI points
# Date 20171218: Daily P&L = -198.00 HSI points
# Date 20171219, Time 235900: End of day - Liquidating 5 short contracts at 29143.0
# Date 20171219: Daily P&L = 642.00 HSI points
# Date 20171220, Time 232400: Last 60 min - Closing 5 short contracts at 29224.0
# Date 20171220: Daily P&L = 89.00 HSI points
# Date 20171221: Daily loss of -443.00 exceeds limit of -200. Stopping trading for today.
# Date 20171221: Daily P&L = -443.00 HSI points
# Date 20171222, Time 235900: End of day - Liquidating 1 long contracts at 29614.0
# Date 20171222: Daily P&L = 76.00 HSI points
# Date 20171227: Daily loss of -230.00 exceeds limit of -200. Stopping trading for today.
# Date 20171227: Daily P&L = -230.00 HSI points
# Date 20171228, Time 235900: End of day - Liquidating 1 long contracts at 29913.0
# Date 20171228: Daily P&L = 8.00 HSI points
# Date 20171229: Daily loss of -244.00 exceeds limit of -200. Stopping trading for today.
# Date 20171229: Daily P&L = -244.00 HSI points
# Date 20180102, Time 233500: Last 60 min - Closing 2 short contracts at 30572.0
# Date 20180102: Daily P&L = -146.00 HSI points
# Date 20180103: Daily loss of -205.00 exceeds limit of -200. Stopping trading for today.
# Date 20180103: Daily P&L = -205.00 HSI points
# Date 20180104, Time 235900: End of day - Liquidating 1 long contracts at 30888.0
# Date 20180104: Daily P&L = 41.00 HSI points
# Date 20180105: Daily loss of -212.00 exceeds limit of -200. Stopping trading for today.
# Date 20180105: Daily P&L = -212.00 HSI points
# Date 20180108: Daily loss of -245.00 exceeds limit of -200. Stopping trading for today.
# Date 20180108: Daily P&L = -245.00 HSI points
# Date 20180109: Daily loss of -248.00 exceeds limit of -200. Stopping trading for today.
# Date 20180109: Daily P&L = -248.00 HSI points
# Date 20180110, Time 233500: Last 60 min - Closing 1 long contracts at 31035.0
# Date 20180110: Daily P&L = 405.00 HSI points
# Date 20180111, Time 233600: Last 60 min - Closing 3 long contracts at 31155.0
# Date 20180111: Daily P&L = 65.00 HSI points
# Date 20180112: Daily loss of -205.00 exceeds limit of -200. Stopping trading for today.
# Date 20180112: Daily P&L = -205.00 HSI points
# Date 20180115: Daily loss of -224.00 exceeds limit of -200. Stopping trading for today.
# Date 20180115: Daily P&L = -224.00 HSI points
# Date 20180116: Daily loss of -223.00 exceeds limit of -200. Stopping trading for today.
# Date 20180116: Daily P&L = -223.00 HSI points
# Date 20180117: Daily loss of -280.00 exceeds limit of -200. Stopping trading for today.
# Date 20180117: Daily P&L = -280.00 HSI points
# Date 20180118: Daily loss of -287.00 exceeds limit of -200. Stopping trading for today.
# Date 20180118: Daily P&L = -287.00 HSI points
# Date 20180119: Daily loss of -359.00 exceeds limit of -200. Stopping trading for today.
# Date 20180119: Daily P&L = -359.00 HSI points
# Date 20180122: Daily loss of -288.00 exceeds limit of -200. Stopping trading for today.
# Date 20180122: Daily P&L = -288.00 HSI points
# Date 20180123: Daily P&L = -4.00 HSI points
# Date 20180124: Daily P&L = -44.00 HSI points
# Date 20180125: Daily loss of -429.00 exceeds limit of -200. Stopping trading for today.
# Date 20180125: Daily P&L = -429.00 HSI points
# Date 20180126: Daily loss of -337.00 exceeds limit of -200. Stopping trading for today.
# Date 20180126: Daily P&L = -337.00 HSI points
# Date 20180129: Daily loss of -597.00 exceeds limit of -200. Stopping trading for today.
# Date 20180129: Daily P&L = -597.00 HSI points
# Date 20180130: Daily loss of -207.00 exceeds limit of -200. Stopping trading for today.
# Date 20180130: Daily P&L = -207.00 HSI points
# Date 20180131: Daily loss of -757.00 exceeds limit of -200. Stopping trading for today.
# Date 20180131: Daily P&L = -757.00 HSI points
# Date 20180201: Daily loss of -210.00 exceeds limit of -200. Stopping trading for today.
# Date 20180201: Daily P&L = -210.00 HSI points
# Date 20180202: Daily loss of -217.00 exceeds limit of -200. Stopping trading for today.
# Date 20180202: Daily P&L = -217.00 HSI points
# Date 20180205: Daily loss of -217.00 exceeds limit of -200. Stopping trading for today.
# Date 20180205: Daily P&L = -217.00 HSI points
# Date 20180206: Daily loss of -619.00 exceeds limit of -200. Stopping trading for today.
# Date 20180206: Daily P&L = -619.00 HSI points
# Date 20180207: Daily loss of -715.00 exceeds limit of -200. Stopping trading for today.
# Date 20180207: Daily P&L = -715.00 HSI points
# Date 20180208: Daily loss of -226.00 exceeds limit of -200. Stopping trading for today.
# Date 20180208: Daily P&L = -226.00 HSI points
# Date 20180209: Daily loss of -259.00 exceeds limit of -200. Stopping trading for today.
# Date 20180209: Daily P&L = -259.00 HSI points
# Date 20180212, Time 230200: Last 60 min - Closing 1 long contracts at 29520.0
# Date 20180212: Daily P&L = 392.00 HSI points
# Date 20180213: Daily loss of -742.00 exceeds limit of -200. Stopping trading for today.
# Date 20180213: Daily P&L = -742.00 HSI points
# Date 20180214: Daily loss of -495.00 exceeds limit of -200. Stopping trading for today.
# Date 20180214: Daily P&L = -495.00 HSI points
# Date 20180215: Daily loss of -560.00 exceeds limit of -200. Stopping trading for today.
# Date 20180215: Daily P&L = -560.00 HSI points
# Date 20180220: Daily P&L = 669.00 HSI points
# Date 20180221: Daily loss of -252.00 exceeds limit of -200. Stopping trading for today.
# Date 20180221: Daily P&L = -252.00 HSI points
# Date 20180222: Daily loss of -230.00 exceeds limit of -200. Stopping trading for today.
# Date 20180222: Daily P&L = -230.00 HSI points
# Date 20180223: Daily loss of -220.00 exceeds limit of -200. Stopping trading for today.
# Date 20180223: Daily P&L = -220.00 HSI points
# Date 20180226: Daily loss of -228.00 exceeds limit of -200. Stopping trading for today.
# Date 20180226: Daily P&L = -228.00 HSI points
# Date 20180227: Daily loss of -240.00 exceeds limit of -200. Stopping trading for today.
# Date 20180227: Daily P&L = -240.00 HSI points
# Date 20180228: Daily loss of -503.00 exceeds limit of -200. Stopping trading for today.
# Date 20180228: Daily P&L = -503.00 HSI points
# Date 20180301: Daily loss of -213.00 exceeds limit of -200. Stopping trading for today.
# Date 20180301: Daily P&L = -213.00 HSI points
# Date 20180302: Daily loss of -237.00 exceeds limit of -200. Stopping trading for today.
# Date 20180302: Daily P&L = -237.00 HSI points
# Date 20180305: Daily loss of -264.00 exceeds limit of -200. Stopping trading for today.
# Date 20180305: Daily P&L = -264.00 HSI points
# Date 20180306: Daily loss of -281.00 exceeds limit of -200. Stopping trading for today.
# Date 20180306: Daily P&L = -281.00 HSI points
# Date 20180307: Daily loss of -211.00 exceeds limit of -200. Stopping trading for today.
# Date 20180307: Daily P&L = -211.00 HSI points
# Date 20180308: Daily loss of -226.00 exceeds limit of -200. Stopping trading for today.
# Date 20180308: Daily P&L = -226.00 HSI points
# Date 20180309, Time 232400: Last 60 min - Closing 4 short contracts at 31184.0
# Date 20180309: Daily P&L = 682.00 HSI points
# Date 20180312, Time 235900: End of day - Liquidating 4 long contracts at 31498.0
# Date 20180312: Daily P&L = -286.00 HSI points
# Date 20180313, Time 231000: Last 60 min - Closing 1 long contracts at 31502.0
# Date 20180313: Daily P&L = 3.00 HSI points
# Date 20180314: Daily loss of -309.00 exceeds limit of -200. Stopping trading for today.
# Date 20180314: Daily P&L = -309.00 HSI points
# Date 20180315: Daily loss of -278.00 exceeds limit of -200. Stopping trading for today.
# Date 20180315: Daily P&L = -278.00 HSI points
# Date 20180316: Daily loss of -295.00 exceeds limit of -200. Stopping trading for today.
# Date 20180316: Daily P&L = -295.00 HSI points
# Date 20180319: Daily loss of -463.00 exceeds limit of -200. Stopping trading for today.
# Date 20180319: Daily P&L = -463.00 HSI points
# Date 20180320: Daily loss of -389.00 exceeds limit of -200. Stopping trading for today.
# Date 20180320: Daily P&L = -389.00 HSI points
# Date 20180321: Daily loss of -242.00 exceeds limit of -200. Stopping trading for today.
# Date 20180321: Daily P&L = -242.00 HSI points
# Date 20180322: Daily loss of -626.00 exceeds limit of -200. Stopping trading for today.
# Date 20180322: Daily P&L = -626.00 HSI points
# Date 20180323: Daily loss of -264.00 exceeds limit of -200. Stopping trading for today.
# Date 20180323: Daily P&L = -264.00 HSI points
# Date 20180326, Time 230600: Last 60 min - Closing 4 long contracts at 30392.0
# Date 20180326: Daily loss of -580.00 exceeds limit of -200. Stopping trading for today.
# Date 20180326: Daily P&L = -580.00 HSI points
# Date 20180327: Daily loss of -209.00 exceeds limit of -200. Stopping trading for today.
# Date 20180327: Daily P&L = -209.00 HSI points
# Date 20180328: Daily loss of -289.00 exceeds limit of -200. Stopping trading for today.
# Date 20180328: Daily P&L = -289.00 HSI points
# Date 20180329: Daily loss of -423.00 exceeds limit of -200. Stopping trading for today.
# Date 20180329: Daily P&L = -423.00 HSI points
# Date 20180403: Daily loss of -244.00 exceeds limit of -200. Stopping trading for today.
# Date 20180403: Daily P&L = -244.00 HSI points
# Date 20180404: Daily loss of -460.00 exceeds limit of -200. Stopping trading for today.
# Date 20180404: Daily P&L = -460.00 HSI points
# Date 20180406: Daily loss of -534.00 exceeds limit of -200. Stopping trading for today.
# Date 20180406: Daily P&L = -534.00 HSI points
# Date 20180409: Daily loss of -431.00 exceeds limit of -200. Stopping trading for today.
# Date 20180409: Daily P&L = -431.00 HSI points
# Date 20180410: Daily loss of -248.00 exceeds limit of -200. Stopping trading for today.
# Date 20180410: Daily P&L = -248.00 HSI points
# Date 20180411: Daily loss of -223.00 exceeds limit of -200. Stopping trading for today.
# Date 20180411: Daily P&L = -223.00 HSI points
# Date 20180412: Daily loss of -214.00 exceeds limit of -200. Stopping trading for today.
# Date 20180412: Daily P&L = -214.00 HSI points
# Date 20180413: Daily loss of -206.00 exceeds limit of -200. Stopping trading for today.
# Date 20180413: Daily P&L = -206.00 HSI points
# Date 20180416: Daily loss of -210.00 exceeds limit of -200. Stopping trading for today.
# Date 20180416: Daily P&L = -210.00 HSI points
# Date 20180417: Daily loss of -334.00 exceeds limit of -200. Stopping trading for today.
# Date 20180417: Daily P&L = -334.00 HSI points
# Date 20180418: Daily loss of -219.00 exceeds limit of -200. Stopping trading for today.
# Date 20180418: Daily P&L = -219.00 HSI points
# Date 20180419: Daily loss of -284.00 exceeds limit of -200. Stopping trading for today.
# Date 20180419: Daily P&L = -284.00 HSI points
# Date 20180420: Daily loss of -293.00 exceeds limit of -200. Stopping trading for today.
# Date 20180420: Daily P&L = -293.00 HSI points
# Date 20180423: Daily loss of -260.00 exceeds limit of -200. Stopping trading for today.
# Date 20180423: Daily P&L = -260.00 HSI points
# Date 20180424: Daily loss of -358.00 exceeds limit of -200. Stopping trading for today.
# Date 20180424: Daily P&L = -358.00 HSI points
# Date 20180425: Daily P&L = 431.00 HSI points
# Date 20180426: Daily loss of -221.00 exceeds limit of -200. Stopping trading for today.
# Date 20180426: Daily P&L = -221.00 HSI points
# Date 20180427: Daily loss of -207.00 exceeds limit of -200. Stopping trading for today.
# Date 20180427: Daily P&L = -207.00 HSI points
# Date 20180430: Daily loss of -285.00 exceeds limit of -200. Stopping trading for today.
# Date 20180430: Daily P&L = -285.00 HSI points
# Date 20180502: Daily loss of -216.00 exceeds limit of -200. Stopping trading for today.
# Date 20180502: Daily P&L = -216.00 HSI points
# Date 20180503: Daily loss of -347.00 exceeds limit of -200. Stopping trading for today.
# Date 20180503: Daily P&L = -347.00 HSI points
# Date 20180504: Daily loss of -451.00 exceeds limit of -200. Stopping trading for today.
# Date 20180504: Daily P&L = -451.00 HSI points
# Date 20180507: Daily loss of -218.00 exceeds limit of -200. Stopping trading for today.
# Date 20180507: Daily P&L = -218.00 HSI points
# Date 20180508: Daily loss of -424.00 exceeds limit of -200. Stopping trading for today.
# Date 20180508: Daily P&L = -424.00 HSI points
# Date 20180509, Time 230300: Last 60 min - Closing 4 long contracts at 30318.0
# Date 20180509: Daily P&L = -181.00 HSI points
# Date 20180510: Daily loss of -212.00 exceeds limit of -200. Stopping trading for today.
# Date 20180510: Daily P&L = -212.00 HSI points
# Date 20180511: Daily loss of -451.00 exceeds limit of -200. Stopping trading for today.
# Date 20180511: Daily P&L = -451.00 HSI points
# Date 20180514, Time 235900: End of day - Liquidating 1 long contracts at 31454.0
# Date 20180514: Daily P&L = 136.00 HSI points
# Date 20180515: Daily P&L = 535.00 HSI points
# Date 20180516: Daily loss of -455.00 exceeds limit of -200. Stopping trading for today.
# Date 20180516: Daily P&L = -455.00 HSI points
# Date 20180517: Daily P&L = 272.00 HSI points
# Date 20180518: Daily loss of -249.00 exceeds limit of -200. Stopping trading for today.
# Date 20180518: Daily P&L = -249.00 HSI points
# Date 20180521, Time 232600: Last 60 min - Closing 1 long contracts at 31213.0
# Date 20180521: Daily P&L = 53.00 HSI points
# Date 20180523: Daily loss of -220.00 exceeds limit of -200. Stopping trading for today.
# Date 20180523: Daily P&L = -220.00 HSI points
# Date 20180524: Daily loss of -254.00 exceeds limit of -200. Stopping trading for today.
# Date 20180524: Daily P&L = -254.00 HSI points
# Date 20180525: Daily loss of -264.00 exceeds limit of -200. Stopping trading for today.
# Date 20180525: Daily P&L = -264.00 HSI points
# Date 20180528, Time 153000: Last 60 min - Closing 1 short contracts at 30817.0
# Date 20180528: Daily P&L = 382.00 HSI points
# Date 20180529: Daily loss of -469.00 exceeds limit of -200. Stopping trading for today.
# Date 20180529: Daily P&L = -469.00 HSI points
# Date 20180530: Daily loss of -241.00 exceeds limit of -200. Stopping trading for today.
# Date 20180530: Daily P&L = -241.00 HSI points
# Date 20180531: Daily loss of -549.00 exceeds limit of -200. Stopping trading for today.
# Date 20180531: Daily P&L = -549.00 HSI points
# Date 20180601: Daily loss of -220.00 exceeds limit of -200. Stopping trading for today.
# Date 20180601: Daily P&L = -220.00 HSI points
# Date 20180604: Daily loss of -298.00 exceeds limit of -200. Stopping trading for today.
# Date 20180604: Daily P&L = -298.00 HSI points
# Date 20180605: Daily loss of -331.00 exceeds limit of -200. Stopping trading for today.
# Date 20180605: Daily P&L = -331.00 HSI points
# Date 20180606: Daily loss of -231.00 exceeds limit of -200. Stopping trading for today.
# Date 20180606: Daily P&L = -231.00 HSI points
# Date 20180607, Time 231400: Last 60 min - Closing 2 long contracts at 31465.0
# Date 20180607: Daily P&L = 146.00 HSI points
# Date 20180608: Daily loss of -270.00 exceeds limit of -200. Stopping trading for today.
# Date 20180608: Daily P&L = -270.00 HSI points
# Date 20180611: Daily loss of -284.00 exceeds limit of -200. Stopping trading for today.
# Date 20180611: Daily P&L = -284.00 HSI points
# Date 20180612: Daily loss of -265.00 exceeds limit of -200. Stopping trading for today.
# Date 20180612: Daily P&L = -265.00 HSI points
# Date 20180613, Time 235900: End of day - Liquidating 4 short contracts at 30780.0
# Date 20180613: Daily P&L = -215.00 HSI points
# Date 20180614, Time 230000: Last 60 min - Closing 1 long contracts at 30461.0
# Date 20180614: Daily loss of -216.00 exceeds limit of -200. Stopping trading for today.
# Date 20180614: Daily P&L = -216.00 HSI points
# Date 20180615: Daily loss of -286.00 exceeds limit of -200. Stopping trading for today.
# Date 20180615: Daily P&L = -286.00 HSI points
# Date 20180619: Daily loss of -270.00 exceeds limit of -200. Stopping trading for today.
# Date 20180619: Daily P&L = -270.00 HSI points
# Date 20180620: Daily loss of -274.00 exceeds limit of -200. Stopping trading for today.
# Date 20180620: Daily P&L = -274.00 HSI points
# Date 20180621: Daily loss of -201.00 exceeds limit of -200. Stopping trading for today.
# Date 20180621: Daily P&L = -201.00 HSI points
# Date 20180622: Daily loss of -461.00 exceeds limit of -200. Stopping trading for today.
# Date 20180622: Daily P&L = -461.00 HSI points
# Date 20180625: Daily loss of -204.00 exceeds limit of -200. Stopping trading for today.
# Date 20180625: Daily P&L = -204.00 HSI points
# Date 20180626: Daily loss of -221.00 exceeds limit of -200. Stopping trading for today.
# Date 20180626: Daily P&L = -221.00 HSI points
# Date 20180627: Daily loss of -322.00 exceeds limit of -200. Stopping trading for today.
# Date 20180627: Daily P&L = -322.00 HSI points
# Date 20180628: Daily loss of -259.00 exceeds limit of -200. Stopping trading for today.
# Date 20180628: Daily P&L = -259.00 HSI points
# Date 20180629, Time 232700: Last 60 min - Closing 1 long contracts at 28702.0
# Date 20180629: Daily P&L = 143.00 HSI points
# Date 20180703: Daily loss of -322.00 exceeds limit of -200. Stopping trading for today.
# Date 20180703: Daily P&L = -322.00 HSI points
# Date 20180704, Time 231400: Last 60 min - Closing 3 long contracts at 28011.0
# Date 20180704: Daily P&L = 457.00 HSI points
# Date 20180705: Daily loss of -207.00 exceeds limit of -200. Stopping trading for today.
# Date 20180705: Daily P&L = -207.00 HSI points
# Date 20180706: Daily loss of -796.00 exceeds limit of -200. Stopping trading for today.
# Date 20180706: Daily P&L = -796.00 HSI points
# Date 20180709, Time 233000: Last 60 min - Closing 2 short contracts at 28790.0
# Date 20180709: Daily P&L = -6.00 HSI points
# Date 20180710: Daily loss of -623.00 exceeds limit of -200. Stopping trading for today.
# Date 20180710: Daily P&L = -623.00 HSI points
# Date 20180711: Daily loss of -201.00 exceeds limit of -200. Stopping trading for today.
# Date 20180711: Daily P&L = -201.00 HSI points
# Date 20180712: Daily loss of -390.00 exceeds limit of -200. Stopping trading for today.
# Date 20180712: Daily P&L = -390.00 HSI points
# Date 20180713: Daily loss of -366.00 exceeds limit of -200. Stopping trading for today.
# Date 20180713: Daily P&L = -366.00 HSI points
# Date 20180716: Daily loss of -207.00 exceeds limit of -200. Stopping trading for today.
# Date 20180716: Daily P&L = -207.00 HSI points
# Date 20180717, Time 235900: End of day - Liquidating 2 short contracts at 28292.0
# Date 20180717: Daily P&L = 163.00 HSI points
# Date 20180718: Daily loss of -247.00 exceeds limit of -200. Stopping trading for today.
# Date 20180718: Daily P&L = -247.00 HSI points
# Date 20180719, Time 235900: End of day - Liquidating 5 short contracts at 27958.0
# Date 20180719: Daily P&L = 132.00 HSI points
# Date 20180720: Daily loss of -217.00 exceeds limit of -200. Stopping trading for today.
# Date 20180720: Daily P&L = -217.00 HSI points
# Date 20180723: Daily loss of -293.00 exceeds limit of -200. Stopping trading for today.
# Date 20180723: Daily P&L = -293.00 HSI points
# Date 20180724, Time 231100: Last 60 min - Closing 1 short contracts at 28854.0
# Date 20180724: Daily P&L = 551.00 HSI points
# Date 20180725, Time 235900: End of day - Liquidating 1 short contracts at 28970.0
# Date 20180725: Daily P&L = -79.00 HSI points
# Date 20180726: Daily loss of -274.00 exceeds limit of -200. Stopping trading for today.
# Date 20180726: Daily P&L = -274.00 HSI points
# Date 20180727: Daily loss of -221.00 exceeds limit of -200. Stopping trading for today.
# Date 20180727: Daily P&L = -221.00 HSI points
# Date 20180730, Time 230500: Last 60 min - Closing 5 long contracts at 28716.0
# Date 20180730: Daily P&L = 255.00 HSI points
# Date 20180731: Daily loss of -464.00 exceeds limit of -200. Stopping trading for today.
# Date 20180731: Daily P&L = -464.00 HSI points
# Date 20180801: Daily loss of -205.00 exceeds limit of -200. Stopping trading for today.
# Date 20180801: Daily P&L = -205.00 HSI points
# Date 20180802: Daily P&L = 400.00 HSI points
# Date 20180803: Daily loss of -272.00 exceeds limit of -200. Stopping trading for today.
# Date 20180803: Daily P&L = -272.00 HSI points
# Date 20180806: Daily loss of -419.00 exceeds limit of -200. Stopping trading for today.
# Date 20180806: Daily P&L = -419.00 HSI points
# Date 20180807: Daily loss of -703.00 exceeds limit of -200. Stopping trading for today.
# Date 20180807: Daily P&L = -703.00 HSI points
# Date 20180808: Daily loss of -256.00 exceeds limit of -200. Stopping trading for today.
# Date 20180808: Daily P&L = -256.00 HSI points
# Date 20180809: Daily loss of -542.00 exceeds limit of -200. Stopping trading for today.
# Date 20180809: Daily P&L = -542.00 HSI points
# Date 20180810: Daily loss of -217.00 exceeds limit of -200. Stopping trading for today.
# Date 20180810: Daily P&L = -217.00 HSI points
# Date 20180813: Daily loss of -224.00 exceeds limit of -200. Stopping trading for today.
# Date 20180813: Daily P&L = -224.00 HSI points
# Date 20180814, Time 235900: End of day - Liquidating 1 long contracts at 27678.0
# Date 20180814: Daily P&L = -145.00 HSI points
# Date 20180815: Daily P&L = 91.00 HSI points
# Date 20180816: Daily loss of -388.00 exceeds limit of -200. Stopping trading for today.
# Date 20180816: Daily P&L = -388.00 HSI points
# Date 20180817, Time 230100: Last 60 min - Closing 1 long contracts at 26950.0
# Date 20180817: Daily P&L = 128.00 HSI points
# Date 20180820, Time 235900: End of day - Liquidating 1 short contracts at 27455.0
# Date 20180820: Daily P&L = 450.00 HSI points
# Date 20180821, Time 231300: Last 60 min - Closing 2 long contracts at 27704.0
# Date 20180821: Daily P&L = -169.00 HSI points
# Date 20180822: Daily loss of -225.00 exceeds limit of -200. Stopping trading for today.
# Date 20180822: Daily P&L = -225.00 HSI points
# Date 20180823, Time 230100: Last 60 min - Closing 4 long contracts at 27701.0
# Date 20180823: Daily P&L = 370.00 HSI points
# Date 20180824: Daily loss of -246.00 exceeds limit of -200. Stopping trading for today.
# Date 20180824: Daily P&L = -246.00 HSI points
# Date 20180827, Time 230700: Last 60 min - Closing 1 short contracts at 28468.0
# Date 20180827: Daily P&L = 189.00 HSI points
# Date 20180828: Daily loss of -208.00 exceeds limit of -200. Stopping trading for today.
# Date 20180828: Daily P&L = -208.00 HSI points
# Date 20180829: Daily loss of -203.00 exceeds limit of -200. Stopping trading for today.
# Date 20180829: Daily P&L = -203.00 HSI points
# Date 20180830: Daily loss of -273.00 exceeds limit of -200. Stopping trading for today.
# Date 20180830: Daily P&L = -273.00 HSI points
# Date 20180831: Daily loss of -201.00 exceeds limit of -200. Stopping trading for today.
# Date 20180831: Daily P&L = -201.00 HSI points
# Date 20180903: Daily loss of -226.00 exceeds limit of -200. Stopping trading for today.
# Date 20180903: Daily P&L = -226.00 HSI points
# Date 20180904, Time 231000: Last 60 min - Closing 1 short contracts at 27684.0
# Date 20180904: Daily P&L = -67.00 HSI points
# Date 20180905, Time 231400: Last 60 min - Closing 2 short contracts at 27026.0
# Date 20180905: Daily loss of -220.00 exceeds limit of -200. Stopping trading for today.
# Date 20180905: Daily P&L = -220.00 HSI points
# Date 20180906: Daily loss of -247.00 exceeds limit of -200. Stopping trading for today.
# Date 20180906: Daily P&L = -247.00 HSI points
# Date 20180907: Daily loss of -937.00 exceeds limit of -200. Stopping trading for today.
# Date 20180907: Daily P&L = -937.00 HSI points
# Date 20180910: Daily loss of -323.00 exceeds limit of -200. Stopping trading for today.
# Date 20180910: Daily P&L = -323.00 HSI points
# Date 20180911: Daily loss of -495.00 exceeds limit of -200. Stopping trading for today.
# Date 20180911: Daily P&L = -495.00 HSI points
# Date 20180912: Daily loss of -334.00 exceeds limit of -200. Stopping trading for today.
# Date 20180912: Daily P&L = -334.00 HSI points
# Date 20180913, Time 230100: Last 60 min - Closing 1 short contracts at 27161.0
# Date 20180913: Daily P&L = 6.00 HSI points
# Date 20180914: Daily loss of -639.00 exceeds limit of -200. Stopping trading for today.
# Date 20180914: Daily P&L = -639.00 HSI points
# Date 20180915: Daily P&L = 0.00 HSI points
# Date 20180917: Daily loss of -257.00 exceeds limit of -200. Stopping trading for today.
# Date 20180917: Daily P&L = -257.00 HSI points
# Date 20180918: Daily P&L = 562.00 HSI points
# Date 20180919: Daily loss of -248.00 exceeds limit of -200. Stopping trading for today.
# Date 20180919: Daily P&L = -248.00 HSI points
# Date 20180920: Daily loss of -343.00 exceeds limit of -200. Stopping trading for today.
# Date 20180920: Daily P&L = -343.00 HSI points
# Date 20180921: Daily loss of -393.00 exceeds limit of -200. Stopping trading for today.
# Date 20180921: Daily P&L = -393.00 HSI points
# Date 20180922: Daily P&L = 0.00 HSI points
# Date 20180924, Time 230900: Last 60 min - Closing 3 short contracts at 27420.0
# Date 20180924: Daily P&L = 347.00 HSI points
# Date 20180925: Daily P&L = 0.00 HSI points
# Date 20180926: Daily loss of -651.00 exceeds limit of -200. Stopping trading for today.
# Date 20180926: Daily P&L = -651.00 HSI points
# Date 20180927: Daily loss of -212.00 exceeds limit of -200. Stopping trading for today.
# Date 20180927: Daily P&L = -212.00 HSI points
# Date 20180928: Daily loss of -258.00 exceeds limit of -200. Stopping trading for today.
# Date 20180928: Daily P&L = -258.00 HSI points
# Date 20180929: Daily P&L = 0.00 HSI points
# Date 20181002: Daily loss of -334.00 exceeds limit of -200. Stopping trading for today.
# Date 20181002: Daily P&L = -334.00 HSI points
# Date 20181003: Daily loss of -393.00 exceeds limit of -200. Stopping trading for today.
# Date 20181003: Daily P&L = -393.00 HSI points
# Date 20181004: Daily loss of -239.00 exceeds limit of -200. Stopping trading for today.
# Date 20181004: Daily P&L = -239.00 HSI points
# Date 20181005: Daily loss of -245.00 exceeds limit of -200. Stopping trading for today.
# Date 20181005: Daily P&L = -245.00 HSI points
# Date 20181006: Daily P&L = 0.00 HSI points
# Date 20181008: Daily loss of -220.00 exceeds limit of -200. Stopping trading for today.
# Date 20181008: Daily P&L = -220.00 HSI points
# Date 20181009: Daily loss of -304.00 exceeds limit of -200. Stopping trading for today.
# Date 20181009: Daily P&L = -304.00 HSI points
# Date 20181010: Daily loss of -224.00 exceeds limit of -200. Stopping trading for today.
# Date 20181010: Daily P&L = -224.00 HSI points
# Date 20181011: Daily loss of -256.00 exceeds limit of -200. Stopping trading for today.
# Date 20181011: Daily P&L = -256.00 HSI points
# Date 20181012: Daily loss of -330.00 exceeds limit of -200. Stopping trading for today.
# Date 20181012: Daily P&L = -330.00 HSI points
# Date 20181013: Daily P&L = 0.00 HSI points
# Date 20181015: Daily loss of -294.00 exceeds limit of -200. Stopping trading for today.
# Date 20181015: Daily P&L = -294.00 HSI points
# Date 20181016: Daily loss of -635.00 exceeds limit of -200. Stopping trading for today.
# Date 20181016: Daily P&L = -635.00 HSI points
# Date 20181017: Daily P&L = 0.00 HSI points
# Date 20181018: Daily loss of -271.00 exceeds limit of -200. Stopping trading for today.
# Date 20181018: Daily P&L = -271.00 HSI points
# Date 20181019: Daily loss of -231.00 exceeds limit of -200. Stopping trading for today.
# Date 20181019: Daily P&L = -231.00 HSI points
# Date 20181020: Daily P&L = 0.00 HSI points
# Date 20181022: Daily loss of -211.00 exceeds limit of -200. Stopping trading for today.
# Date 20181022: Daily P&L = -211.00 HSI points
# Date 20181023, Time 230800: Last 60 min - Closing 1 short contracts at 25198.0
# Date 20181023: Daily P&L = 863.00 HSI points
# Date 20181024: Daily loss of -212.00 exceeds limit of -200. Stopping trading for today.
# Date 20181024: Daily P&L = -212.00 HSI points
# Date 20181025, Time 230100: Last 60 min - Closing 3 long contracts at 25031.0
# Date 20181025: Daily P&L = 2364.00 HSI points
# Date 20181026: Daily loss of -264.00 exceeds limit of -200. Stopping trading for today.
# Date 20181026: Daily P&L = -264.00 HSI points
# Date 20181027: Daily P&L = 0.00 HSI points
# Date 20181029: Daily loss of -218.00 exceeds limit of -200. Stopping trading for today.
# Date 20181029: Daily P&L = -218.00 HSI points
# Date 20181030: Daily loss of -230.00 exceeds limit of -200. Stopping trading for today.
# Date 20181030: Daily P&L = -230.00 HSI points
# Date 20181031: Daily P&L = -57.00 HSI points
# Date 20181101: Daily loss of -231.00 exceeds limit of -200. Stopping trading for today.
# Date 20181101: Daily P&L = -231.00 HSI points
# Date 20181102: Daily loss of -382.00 exceeds limit of -200. Stopping trading for today.
# Date 20181102: Daily P&L = -382.00 HSI points
# Date 20181103: Daily P&L = 0.00 HSI points
# Date 20181105: Daily loss of -210.00 exceeds limit of -200. Stopping trading for today.
# Date 20181105: Daily P&L = -210.00 HSI points
# Date 20181106: Daily P&L = 174.00 HSI points
# Date 20181107: Daily loss of -317.00 exceeds limit of -200. Stopping trading for today.
# Date 20181107: Daily P&L = -317.00 HSI points
# Date 20181108: Daily loss of -769.00 exceeds limit of -200. Stopping trading for today.
# Date 20181108: Daily P&L = -769.00 HSI points
# Date 20181109, Time 230000: Last 60 min - Closing 4 long contracts at 25396.0
# Date 20181109: Daily P&L = 521.00 HSI points
# Date 20181110: Daily P&L = 0.00 HSI points
# Date 20181112: Daily loss of -216.00 exceeds limit of -200. Stopping trading for today.
# Date 20181112: Daily P&L = -216.00 HSI points
# Date 20181113: Daily loss of -253.00 exceeds limit of -200. Stopping trading for today.
# Date 20181113: Daily P&L = -253.00 HSI points
# Date 20181114: Daily loss of -896.00 exceeds limit of -200. Stopping trading for today.
# Date 20181114: Daily P&L = -896.00 HSI points
# Date 20181115: Daily loss of -439.00 exceeds limit of -200. Stopping trading for today.
# Date 20181115: Daily P&L = -439.00 HSI points
# Date 20181116: Daily loss of -215.00 exceeds limit of -200. Stopping trading for today.
# Date 20181116: Daily P&L = -215.00 HSI points
# Date 20181117: Daily P&L = 0.00 HSI points
# Date 20181119: Daily loss of -499.00 exceeds limit of -200. Stopping trading for today.
# Date 20181119: Daily P&L = -499.00 HSI points
# Date 20181120: Daily loss of -325.00 exceeds limit of -200. Stopping trading for today.
# Date 20181120: Daily P&L = -325.00 HSI points
# Date 20181121: Daily loss of -236.00 exceeds limit of -200. Stopping trading for today.
# Date 20181121: Daily P&L = -236.00 HSI points
# Date 20181122, Time 232500: Last 60 min - Closing 2 long contracts at 25877.0
# Date 20181122: Daily loss of -274.00 exceeds limit of -200. Stopping trading for today.
# Date 20181122: Daily P&L = -274.00 HSI points
# Date 20181123: Daily loss of -220.00 exceeds limit of -200. Stopping trading for today.
# Date 20181123: Daily P&L = -220.00 HSI points
# Date 20181124: Daily P&L = 0.00 HSI points
# Date 20181126: Daily loss of -227.00 exceeds limit of -200. Stopping trading for today.
# Date 20181126: Daily P&L = -227.00 HSI points
# Date 20181127: Daily loss of -280.00 exceeds limit of -200. Stopping trading for today.
# Date 20181127: Daily P&L = -280.00 HSI points
# Date 20181128: Daily loss of -410.00 exceeds limit of -200. Stopping trading for today.
# Date 20181128: Daily P&L = -410.00 HSI points
# Date 20181129: Daily loss of -227.00 exceeds limit of -200. Stopping trading for today.
# Date 20181129: Daily P&L = -227.00 HSI points
# Date 20181130: Daily loss of -224.00 exceeds limit of -200. Stopping trading for today.
# Date 20181130: Daily P&L = -224.00 HSI points
# Date 20181201: Daily P&L = 0.00 HSI points
# Date 20181203: Daily loss of -245.00 exceeds limit of -200. Stopping trading for today.
# Date 20181203: Daily P&L = -245.00 HSI points
# Date 20181204: Daily loss of -338.00 exceeds limit of -200. Stopping trading for today.
# Date 20181204: Daily P&L = -338.00 HSI points
# Date 20181205, Time 233100: Last 60 min - Closing 2 long contracts at 26831.0
# Date 20181205: Daily P&L = 240.00 HSI points
# Date 20181206: Daily loss of -355.00 exceeds limit of -200. Stopping trading for today.
# Date 20181206: Daily P&L = -355.00 HSI points
# Date 20181207: Daily loss of -215.00 exceeds limit of -200. Stopping trading for today.
# Date 20181207: Daily P&L = -215.00 HSI points
# Date 20181208: Daily P&L = 0.00 HSI points
# Date 20181210: Daily loss of -289.00 exceeds limit of -200. Stopping trading for today.
# Date 20181210: Daily P&L = -289.00 HSI points
# Date 20181211: Daily loss of -218.00 exceeds limit of -200. Stopping trading for today.
# Date 20181211: Daily P&L = -218.00 HSI points
# Date 20181212, Time 231700: Last 60 min - Closing 4 short contracts at 26445.0
# Date 20181212: Daily P&L = 200.00 HSI points
# Date 20181213, Time 230000: Last 60 min - Closing 1 long contracts at 26425.0
# Date 20181213: Daily P&L = 175.00 HSI points
# Date 20181214: Daily loss of -307.00 exceeds limit of -200. Stopping trading for today.
# Date 20181214: Daily P&L = -307.00 HSI points
# Date 20181215: Daily P&L = 0.00 HSI points
# Date 20181217: Daily P&L = 55.00 HSI points
# Date 20181218, Time 230000: Last 60 min - Closing 3 long contracts at 25983.0
# Date 20181218: Daily P&L = 156.00 HSI points
# Date 20181219, Time 232700: Last 60 min - Closing 1 long contracts at 26062.0
# Date 20181219: Daily P&L = 748.00 HSI points
# Date 20181220: Daily loss of -753.00 exceeds limit of -200. Stopping trading for today.
# Date 20181220: Daily P&L = -753.00 HSI points
# Date 20181221: Daily loss of -413.00 exceeds limit of -200. Stopping trading for today.
# Date 20181221: Daily P&L = -413.00 HSI points
# Date 20181222: Daily P&L = 0.00 HSI points
# Date 20181224: Daily loss of -256.00 exceeds limit of -200. Stopping trading for today.
# Date 20181224: Daily P&L = -256.00 HSI points
# Date 20181227: Daily loss of -219.00 exceeds limit of -200. Stopping trading for today.
# Date 20181227: Daily P&L = -219.00 HSI points
# Date 20181228, Time 230000: Last 60 min - Closing 1 long contracts at 25729.0
# Date 20181228: Daily P&L = 593.00 HSI points
# Date 20181229: Daily P&L = 0.00 HSI points
# Date 20181231: Daily P&L = -52.00 HSI points
# ...
# Date 20191213: Daily loss of -208.00 exceeds limit of -200. Stopping trading for today.
# Date 20191213: Daily P&L = -208.00 HSI points
# Date 20191214, Time 030000: End of day - Liquidating 1 short contracts at 27511.0
# Date 20191214: Daily P&L = 66.00 HSI points
# Date 20191216: Daily loss of -808.00 exceeds limit of -200. Stopping trading for today.
# Date 20191216: Daily P&L = -808.00 HSI points
# Date 20191217: Daily loss of -227.00 exceeds limit of -200. Stopping trading for today.
# Date 20191217: Daily P&L = -227.00 HSI points
# Date 20191218: Daily P&L = -132.00 HSI points
# Date 20191219, Time 230200: Last 60 min - Closing 5 short contracts at 27788.0
# Date 20191219: Daily P&L = 1238.00 HSI points
# Date 20191220, Time 232200: Last 60 min - Closing 5 long contracts at 28021.0
# Date 20191220: Daily P&L = 3514.00 HSI points
# Date 20191221, Time 020500: Last 60 min - Closing 5 short contracts at 27947.0
# Date 20191221: Daily P&L = -66.00 HSI points
# Date 20191223: Daily P&L = 18267.00 HSI points
# Date 20191224, Time 113300: Last 60 min - Closing 4 long contracts at 27953.0
# Date 20191224: Daily P&L = 8303.00 HSI points
# Date 20191227, Time 230400: Last 60 min - Closing 1 short contracts at 28213.0
# Date 20191227: Daily P&L = 36058.00 HSI points
# Date 20191228, Time 020100: Last 60 min - Closing 5 long contracts at 28333.0
# Date 20191228: Daily P&L = 3671.00 HSI points
# Date 20191230: Daily loss of -322.00 exceeds limit of -200. Stopping trading for today.
# Date 20191230: Daily P&L = -322.00 HSI points
# Date 20191231, Time 122900: End of day - Liquidating 1 long contracts at 28270.0
# Date 20191231: Daily P&L = -16.00 HSI points
# Date 20200102: Daily loss of -262.00 exceeds limit of -200. Stopping trading for today.
# Date 20200102: Daily P&L = -262.00 HSI points
# Date 20200103: Daily loss of -374.00 exceeds limit of -200. Stopping trading for today.
# Date 20200103: Daily P&L = -374.00 HSI points
# Date 20200104, Time 021300: Last 60 min - Closing 5 short contracts at 28453.0
# Date 20200104: Daily P&L = 115.00 HSI points
# Date 20200106: Daily loss of -203.00 exceeds limit of -200. Stopping trading for today.
# Date 20200106: Daily P&L = -203.00 HSI points
# Date 20200107: Daily loss of -221.00 exceeds limit of -200. Stopping trading for today.
# Date 20200107: Daily P&L = -221.00 HSI points
# Date 20200108: Daily P&L = 1367.00 HSI points
# Date 20200109, Time 231700: Last 60 min - Closing 5 long contracts at 28531.0
# Date 20200109: Daily P&L = 152.00 HSI points
# Date 20200110: Daily loss of -205.00 exceeds limit of -200. Stopping trading for today.
# Date 20200110: Daily P&L = -205.00 HSI points
# Date 20200111: Daily P&L = 5.00 HSI points
# Date 20200113: Daily loss of -938.00 exceeds limit of -200. Stopping trading for today.
# Date 20200113: Daily P&L = -938.00 HSI points
# Date 20200114: Daily loss of -224.00 exceeds limit of -200. Stopping trading for today.
# Date 20200114: Daily P&L = -224.00 HSI points
# Date 20200115: Daily loss of -236.00 exceeds limit of -200. Stopping trading for today.
# Date 20200115: Daily P&L = -236.00 HSI points
# Date 20200116: Daily loss of -317.00 exceeds limit of -200. Stopping trading for today.
# Date 20200116: Daily P&L = -317.00 HSI points
# Date 20200117: Daily loss of -869.00 exceeds limit of -200. Stopping trading for today.
# Date 20200117: Daily P&L = -869.00 HSI points
# Date 20200118: Daily P&L = 0.00 HSI points
# Date 20200120: Daily loss of -621.00 exceeds limit of -200. Stopping trading for today.
# Date 20200120: Daily P&L = -621.00 HSI points
# Date 20200121: Daily loss of -252.00 exceeds limit of -200. Stopping trading for today.
# Date 20200121: Daily P&L = -252.00 HSI points
# Date 20200122: Daily loss of -204.00 exceeds limit of -200. Stopping trading for today.
# Date 20200122: Daily P&L = -204.00 HSI points
# Date 20200123, Time 230500: Last 60 min - Closing 2 short contracts at 27651.0
# Date 20200123: Daily P&L = 631.00 HSI points
# Date 20200124: Daily loss of -515.00 exceeds limit of -200. Stopping trading for today.
# Date 20200124: Daily P&L = -515.00 HSI points
# Date 20200129: Daily loss of -274.00 exceeds limit of -200. Stopping trading for today.
# Date 20200129: Daily P&L = -274.00 HSI points
# Date 20200130: Daily loss of -251.00 exceeds limit of -200. Stopping trading for today.
# Date 20200130: Daily P&L = -251.00 HSI points
# Date 20200131: Daily loss of -230.00 exceeds limit of -200. Stopping trading for today.
# Date 20200131: Daily P&L = -230.00 HSI points
# Date 20200201, Time 020400: Last 60 min - Closing 2 long contracts at 25915.0
# Date 20200201: Daily P&L = -141.00 HSI points
# Date 20200203: Daily loss of -216.00 exceeds limit of -200. Stopping trading for today.
# Date 20200203: Daily P&L = -216.00 HSI points
# Date 20200204: Daily loss of -275.00 exceeds limit of -200. Stopping trading for today.
# Date 20200204: Daily P&L = -275.00 HSI points
# Date 20200205: Daily loss of -225.00 exceeds limit of -200. Stopping trading for today.
# Date 20200205: Daily P&L = -225.00 HSI points
# Date 20200206: Daily loss of -249.00 exceeds limit of -200. Stopping trading for today.
# Date 20200206: Daily P&L = -249.00 HSI points
# Date 20200207: Daily P&L = 266.00 HSI points
# Date 20200208: Daily P&L = 48.00 HSI points
# Date 20200210: Daily P&L = 127.00 HSI points
# Date 20200211: Daily loss of -235.00 exceeds limit of -200. Stopping trading for today.
# Date 20200211: Daily P&L = -235.00 HSI points
# Date 20200212: Daily P&L = 418.00 HSI points
# Date 20200213, Time 233400: Last 60 min - Closing 2 short contracts at 27575.0
# Date 20200213: Daily P&L = 154.00 HSI points
# Date 20200214: Daily loss of -505.00 exceeds limit of -200. Stopping trading for today.
# Date 20200214: Daily P&L = -505.00 HSI points
# Date 20200215: Daily P&L = -21.00 HSI points
# Date 20200217, Time 235900: End of day - Liquidating 5 long contracts at 27868.0
# Date 20200217: Daily P&L = 125.00 HSI points
# Date 20200218: Daily P&L = -33.00 HSI points
# Date 20200219: Daily loss of -280.00 exceeds limit of -200. Stopping trading for today.
# Date 20200219: Daily P&L = -280.00 HSI points
# Date 20200220: Daily loss of -220.00 exceeds limit of -200. Stopping trading for today.
# Date 20200220: Daily P&L = -220.00 HSI points
# Date 20200221: Daily loss of -280.00 exceeds limit of -200. Stopping trading for today.
# Date 20200221: Daily P&L = -280.00 HSI points
# Date 20200222, Time 020100: Last 60 min - Closing 4 long contracts at 27311.0
# Date 20200222: Daily P&L = 29.00 HSI points
# Date 20200224, Time 230200: Last 60 min - Closing 2 long contracts at 26457.0
# Date 20200224: Daily P&L = 6.00 HSI points
# Date 20200225: Daily loss of -223.00 exceeds limit of -200. Stopping trading for today.
# Date 20200225: Daily P&L = -223.00 HSI points
# Date 20200226: Daily loss of -268.00 exceeds limit of -200. Stopping trading for today.
# Date 20200226: Daily P&L = -268.00 HSI points
# Date 20200227: Daily loss of -228.00 exceeds limit of -200. Stopping trading for today.
# Date 20200227: Daily P&L = -228.00 HSI points
# Date 20200228: Daily loss of -292.00 exceeds limit of -200. Stopping trading for today.
# Date 20200228: Daily P&L = -292.00 HSI points
# Date 20200229, Time 020900: Last 60 min - Closing 1 long contracts at 26009.0
# Date 20200229: Daily P&L = -84.00 HSI points
# Date 20200302: Daily loss of -289.00 exceeds limit of -200. Stopping trading for today.
# Date 20200302: Daily P&L = -289.00 HSI points
# Date 20200303, Time 230000: Last 60 min - Closing 3 short contracts at 26536.0
# Date 20200303: Daily P&L = 110.00 HSI points
# Date 20200304: Daily loss of -253.00 exceeds limit of -200. Stopping trading for today.
# Date 20200304: Daily P&L = -253.00 HSI points
# Date 20200305: Daily loss of -209.00 exceeds limit of -200. Stopping trading for today.
# Date 20200305: Daily P&L = -209.00 HSI points
# Date 20200306: Daily loss of -257.00 exceeds limit of -200. Stopping trading for today.
# Date 20200306: Daily P&L = -257.00 HSI points
# Date 20200307: Daily P&L = 90.00 HSI points
# Date 20200309: Daily loss of -791.00 exceeds limit of -200. Stopping trading for today.
# Date 20200309: Daily P&L = -791.00 HSI points
# Date 20200310: Daily loss of -364.00 exceeds limit of -200. Stopping trading for today.
# Date 20200310: Daily P&L = -364.00 HSI points
# Date 20200311: Daily loss of -252.00 exceeds limit of -200. Stopping trading for today.
# Date 20200311: Daily P&L = -252.00 HSI points
# Date 20200312: Daily loss of -361.00 exceeds limit of -200. Stopping trading for today.
# Date 20200312: Daily P&L = -361.00 HSI points
# Date 20200313: Daily loss of -248.00 exceeds limit of -200. Stopping trading for today.
# Date 20200313: Daily P&L = -248.00 HSI points
# Date 20200314: Daily loss of -259.00 exceeds limit of -200. Stopping trading for today.
# Date 20200314: Daily P&L = -259.00 HSI points
# Date 20200316: Daily loss of -685.00 exceeds limit of -200. Stopping trading for today.
# Date 20200316: Daily P&L = -685.00 HSI points
# Date 20200317: Daily loss of -432.00 exceeds limit of -200. Stopping trading for today.
# Date 20200317: Daily P&L = -432.00 HSI points
# Date 20200318: Daily loss of -238.00 exceeds limit of -200. Stopping trading for today.
# Date 20200318: Daily P&L = -238.00 HSI points
# Date 20200319, Time 153100: Last 60 min - Closing 3 short contracts at 21881.0
# Date 20200319: Daily P&L = 1722.00 HSI points
# Date 20200320: Daily loss of -310.00 exceeds limit of -200. Stopping trading for today.
# Date 20200320: Daily P&L = -310.00 HSI points
# Date 20200323, Time 153100: Last 60 min - Closing 1 short contracts at 21682.0
# Date 20200323: Daily P&L = 767.00 HSI points
# Date 20200324, Time 153700: Last 60 min - Closing 6 short contracts at 22634.0
# Date 20200324: Daily P&L = 1065.00 HSI points
# Date 20200325: Daily loss of -490.00 exceeds limit of -200. Stopping trading for today.
# Date 20200325: Daily P&L = -490.00 HSI points
# Date 20200326: Daily loss of -217.00 exceeds limit of -200. Stopping trading for today.
# Date 20200326: Daily P&L = -217.00 HSI points
# Date 20200327: Daily loss of -340.00 exceeds limit of -200. Stopping trading for today.
# Date 20200327: Daily P&L = -340.00 HSI points
# Date 20200330: Daily loss of -203.00 exceeds limit of -200. Stopping trading for today.
# Date 20200330: Daily P&L = -203.00 HSI points
# Date 20200331: Daily loss of -212.00 exceeds limit of -200. Stopping trading for today.
# Date 20200331: Daily P&L = -212.00 HSI points
# Date 20200401, Time 153500: Last 60 min - Closing 6 short contracts at 22928.0
# Date 20200401: Daily P&L = 544.00 HSI points
# Date 20200402: Daily loss of -217.00 exceeds limit of -200. Stopping trading for today.
# Date 20200402: Daily P&L = -217.00 HSI points
# Date 20200403, Time 161000: Last 60 min - Closing 2 long contracts at 23223.0
# Date 20200403: Daily P&L = 89.00 HSI points
# Date 20200406: Daily loss of -398.00 exceeds limit of -200. Stopping trading for today.
# Date 20200406: Daily P&L = -398.00 HSI points
# Date 20200407: Daily loss of -684.00 exceeds limit of -200. Stopping trading for today.
# Date 20200407: Daily P&L = -684.00 HSI points
# Date 20200408: Daily loss of -242.00 exceeds limit of -200. Stopping trading for today.
# Date 20200408: Daily P&L = -242.00 HSI points
# Date 20200409: Daily loss of -322.00 exceeds limit of -200. Stopping trading for today.
# Date 20200409: Daily P&L = -322.00 HSI points
# Date 20200414: Daily P&L = 256.00 HSI points
# Date 20200415, Time 153300: Last 60 min - Closing 4 short contracts at 24176.0
# Date 20200415: Daily P&L = -121.00 HSI points
# Date 20200416, Time 160400: Last 60 min - Closing 5 short contracts at 24014.0
# Date 20200416: Daily P&L = 487.00 HSI points
# Date 20200417: Daily P&L = 548.00 HSI points
# Date 20200420, Time 162900: End of day - Liquidating 2 short contracts at 24280.0
# Date 20200420: Daily P&L = 56.00 HSI points
# Date 20200421, Time 154300: Last 60 min - Closing 1 short contracts at 23753.0
# Date 20200421: Daily P&L = 33.00 HSI points
# Date 20200422: Daily loss of -215.00 exceeds limit of -200. Stopping trading for today.
# Date 20200422: Daily P&L = -215.00 HSI points
# Date 20200423: Daily loss of -205.00 exceeds limit of -200. Stopping trading for today.
# Date 20200423: Daily P&L = -205.00 HSI points
# Date 20200424, Time 153800: Last 60 min - Closing 1 long contracts at 23889.0
# Date 20200424: Daily P&L = -197.00 HSI points
# Date 20200427: Daily loss of -205.00 exceeds limit of -200. Stopping trading for today.
# Date 20200427: Daily P&L = -205.00 HSI points
# Date 20200428: Daily loss of -279.00 exceeds limit of -200. Stopping trading for today.
# Date 20200428: Daily P&L = -279.00 HSI points
# Date 20200429: Daily loss of -208.00 exceeds limit of -200. Stopping trading for today.
# Date 20200429: Daily P&L = -208.00 HSI points
# Date 20200504: Daily P&L = -96.00 HSI points
# Date 20200505: Daily loss of -257.00 exceeds limit of -200. Stopping trading for today.
# Date 20200505: Daily P&L = -257.00 HSI points
# Date 20200506: Daily loss of -203.00 exceeds limit of -200. Stopping trading for today.
# Date 20200506: Daily P&L = -203.00 HSI points
# Date 20200507: Daily loss of -206.00 exceeds limit of -200. Stopping trading for today.
# Date 20200507: Daily P&L = -206.00 HSI points
# Date 20200508, Time 162700: Last 60 min - Closing 2 short contracts at 24128.0
# Date 20200508: Daily P&L = -194.00 HSI points
# Date 20200511: Daily loss of -215.00 exceeds limit of -200. Stopping trading for today.
# Date 20200511: Daily P&L = -215.00 HSI points
# Date 20200512: Daily loss of -213.00 exceeds limit of -200. Stopping trading for today.
# Date 20200512: Daily P&L = -213.00 HSI points
# Date 20200513: Daily P&L = 39.00 HSI points
# Date 20200514: Daily loss of -203.00 exceeds limit of -200. Stopping trading for today.
# Date 20200514: Daily P&L = -203.00 HSI points
# Date 20200515: Daily loss of -213.00 exceeds limit of -200. Stopping trading for today.
# Date 20200515: Daily P&L = -213.00 HSI points
# Date 20200518, Time 153500: Last 60 min - Closing 1 long contracts at 23836.0
# Date 20200518: Daily P&L = 108.00 HSI points
# Date 20200519: Daily loss of -540.00 exceeds limit of -200. Stopping trading for today.
# Date 20200519: Daily P&L = -540.00 HSI points
# Date 20200520, Time 161500: Last 60 min - Closing 2 short contracts at 24385.0
# Date 20200520: Daily P&L = -120.00 HSI points
# Date 20200521, Time 162900: End of day - Liquidating 2 short contracts at 24128.0
# Date 20200521: Daily P&L = 189.00 HSI points
# Date 20200522: Daily loss of -386.00 exceeds limit of -200. Stopping trading for today.
# Date 20200522: Daily P&L = -386.00 HSI points
# Date 20200525: Daily P&L = 6.00 HSI points
# Date 20200526: Daily loss of -221.00 exceeds limit of -200. Stopping trading for today.
# Date 20200526: Daily P&L = -221.00 HSI points
# Date 20200527, Time 162900: End of day - Liquidating 1 short contracts at 23205.0
# Date 20200527: Daily P&L = -221.00 HSI points
# Date 20200528: Daily loss of -242.00 exceeds limit of -200. Stopping trading for today.
# Date 20200528: Daily P&L = -242.00 HSI points
# Date 20200529: Daily loss of -302.00 exceeds limit of -200. Stopping trading for today.
# Date 20200529: Daily P&L = -302.00 HSI points
# Date 20200601: Daily loss of -270.00 exceeds limit of -200. Stopping trading for today.
# Date 20200601: Daily P&L = -270.00 HSI points
# Date 20200602, Time 153100: Last 60 min - Closing 4 short contracts at 23810.0
# Date 20200602: Daily loss of -274.00 exceeds limit of -200. Stopping trading for today.
# Date 20200602: Daily P&L = -274.00 HSI points
# Date 20200603, Time 160900: Last 60 min - Closing 2 short contracts at 24206.0
# Date 20200603: Daily P&L = -98.00 HSI points
# Date 20200604, Time 153400: Last 60 min - Closing 4 long contracts at 24166.0
# Date 20200604: Daily P&L = 86.00 HSI points
# Date 20200605: Daily loss of -430.00 exceeds limit of -200. Stopping trading for today.
# Date 20200605: Daily P&L = -430.00 HSI points
# Date 20200608, Time 154900: Last 60 min - Closing 4 long contracts at 24645.0
# Date 20200608: Daily loss of -319.00 exceeds limit of -200. Stopping trading for today.
# Date 20200608: Daily P&L = -319.00 HSI points
# Date 20200609: Daily loss of -218.00 exceeds limit of -200. Stopping trading for today.
# Date 20200609: Daily P&L = -218.00 HSI points

# %%
# Calculate final results
print("\nTrading Results Summary:")
print(f"Total P&L: {total_profit:.2f} HSI points (HKD {total_profit * 50:.2f})")
print(f"Number of trading days: {len(daily_profits)}")
print(f"Average daily P&L: {np.mean(daily_profits):.2f} HSI points")
print(f"Best day: {np.max(daily_profits):.2f} HSI points")
print(f"Worst day: {np.min(daily_profits):.2f} HSI points")

import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
plt.plot(daily_profits, label='profit')
plt.xlabel('date')
plt.ylabel('profit')
plt.legend()
plt.grid(True)

plt.savefig('profit111200.png', dpi=300)
plt.show()
# Out:
# Trading Results Summary:
# Total P&L: 40918.00 HSI points (HKD 2045900.00)
# Number of trading days: 806
# Average daily P&L: 50.77 HSI points
# Best day: 36058.00 HSI points
# Worst day: -938.00 HSI points
